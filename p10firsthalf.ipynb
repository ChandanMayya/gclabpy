# %%
import pandas as pd

# %%
df=pd.read_csv("AirPassengers.csv")
print(df.head())
print(df.tail())
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
df['Month']=pd.to_datetime(df['Month'],format='%Y-%m')
print(df.head())
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
df.index=df['Month']
del df['Month']
print(df.head())
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(df)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.ylabel("Number of Passengers")
rolling_mean=df.rolling(7).mean()
rolling_std=df.rolling(7).std()

plt.plot(df,color="blue",label="Original Passenger Data")
plt.plot(rolling_mean,color="red",label="Rolling mean Passenger Number")
plt.plot(rolling_std,color="orange",label="Rolling standard Deviation in Passenger Number")
plt.title("Passenger Time Series, Rolling Mean, Standard Deviation")
# Out:
# Text(0.5, 1.0, 'Passenger Time Series, Rolling Mean, Standard Deviation')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decompose = seasonal_decompose(df['#Passengers'],model='additive',period=7)
decompose.plot()
plt.show()

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows=250

# %%
pd.options.display.max_rows
# Out:
# 250
