# %%
import numpy as np
lt = []
n=int(input("Enter number of elements:"))
for i in range(0,n):
    ele=int(input())
    lt.append(ele)
print(lt)
arr=np.array(lt)
arr=np.sort(arr)
print("sorted Array:{}".format(arr))
ele=int(input("Enter element to search: "))
i=np.where(arr==ele)
print("index={}",format(i))
s=int(input("Enter splitting value: "))
newarr=np.array_split(arr,s)
print(newarr)
# Out:
# Enter number of elements:3
# 3
# 6
# 2
# [3, 6, 2]
# sorted Array:[2 3 6]
# Enter element to search: 3
# index={} (array([1]),)
# Enter splitting value: 2
# [array([2, 3]), array([6])]

# %%
import numpy as np
from numpy import array,argmin,sqrt,sum
observation=array([111.0,188.0])
codes=array([[102.0,203.0],[132.0,193.0],[45.0,155.0],[57.0,173.0]])
diff=codes-observation
dist=sqrt(sum(diff**2,axis=-1))
print(observation,observation.shape)
print(codes,codes.shape)
print(diff,diff.shape)
print(dist,dist.shape)
argmin(dist)
# Out:
# [111. 188.] (2,)
# [[102. 203.]
#  [132. 193.]
#  [ 45. 155.]
#  [ 57. 173.]] (4, 2)
# [[ -9.  15.]
#  [ 21.   5.]
#  [-66. -33.]
#  [-54. -15.]] (4, 2)
# [17.49285568 21.58703314 73.79024326 56.04462508] (4,)
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,3*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.plot(x,y_sin)
plt.plot(x,y_cos)
plt.xlabel("x axis label")
plt.ylabel("y axis label")
plt.title("Sine and cosine")
plt.legend(['Sine','Cosine'])
plt.show()

# %%
lst=[]
while(True):
    str=input("Enter a string (Done to end)")
    if str=="Done":
        break
    else:
        lst.append(str)

for str in range(0,len(lst)):
    if not( str%2==0 ) and (str!=0 or str!=1) :
        print(lst[str][::-1])
    else:
        print(lst[str])
# Out:
# Enter a string (Done to end)hi
# Enter a string (Done to end)hey
# Enter a string (Done to end)hello
# Enter a string (Done to end)hola
# Enter a string (Done to end)amigo
# Enter a string (Done to end)Done
# hi
# yeh
# hello
# aloh
# amigo

# %%
lst=[1,2,3,4,5]
print(lst[::-1])
# Out:
# [5, 4, 3, 2, 1]

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,4,6,8])
y=x*2
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(20,5),columns=['A','B','C','D','E'])
df.plot.box(grid="True")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
x=[74,88,52,72,78]
y=[23,22,54,69,80]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
y=[1,15,19,40,65]
plt.hist(y)
plt.show()

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
data=[{8,9,3,4,},{4,6,9,1},{7,4,1,3},{9,5,1,3,},{7,1,3,4}]
Index=['I1','I2','I3','I4','I5']
cols=['C1','C2','C3','C4']
df=DataFrame(data,index=Index,columns=cols)
plt.pcolor(df)
plt.show()

# %%
from matplotlib import pyplot
import random
data=[[random.randint(0,256) for x in range(0,5)],
     [random.randint(0,256) for x in range(0,5)],
      [random.randint(0,256) for x in range(0,5)],
      [random.randint(0,256) for x in range(0,5)],
      [random.randint(0,256) for x in range(0,5)],
      [random.randint(0,256) for x in range(0,5)]
     ]

data


from matplotlib import colors
pyplot.figure(figsize=(5,5))
pyplot.xlabel("x axis with ticks",size=8)
pyplot.ylabel("y axis with ticks",size=8)
pyplot.xticks(size=14,color="red")
pyplot.yticks(size=14,color="red")
colormap=colors.ListedColormap(["orange","green"])
pyplot.imshow(data,cmap=colormap)

#program to print m*n matrix array using matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={'year':[1920,1930,1940,1950,1960,1970,1980,1990,2000,2010],'unemployment_rate':[9.8,12,8,7.2,6.9,6.2,5.5,6.3,5.5,6.4]}
df=pd.DataFrame(data)
plt.plot(df['year'],df['unemployment_rate'],color='red',marker='p')
plt.title('unemployment rate vs year',fontsize=14)
plt.xlabel('year',fontsize=14)
plt.ylabel('unemployment_rate',fontsize=14)
plt.legend("Line Graph")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,9,6])
y=np.array([99,86,87,88,111,86,103,87,99,78,77,85])
plt.scatter(x,y)
plt.title("Scatter graph",fontsize=14)
plt.xlabel("x axis",fontsize=12)
plt.ylabel("y axis",fontsize=12)
plt.legend("HI")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,width=0.5,color="orange")
plt.show()
plt=20

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
dataSet1=np.random.normal(100,10,220)
dataSet2=np.random.normal(80,20,200)
dataSet3=np.random.normal(60,35,220)
dataSet4=np.random.normal(50,40,200)
dataSet=[dataSet1,dataSet2,dataSet3,dataSet4]
figure=plt.figure(figsize=(10,7))
ax=figure.add_axes([0,0,1,1])
bp=ax.boxplot(dataSet)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig.ax=subplots(1,1)
a=np.array([22,87,5,43,56,73,55,45,11,20,51,5,79,31,27])
ax.hist(a,bins=[0,25,50,75,100])
ax.set_title("histogram of results")

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
data=[{8,9,3,4},{4,6,9,1},{7,4,1,3},{7,1,3,9}]
Index=['l1','l2','l3','l4','l5']
cols=['C1','C2','C3','C4']
df=DataFrame(data,index=Index,columns=cols) 
plt.pcolor(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1773         blocks = _form_blocks(arrays, names, axes, consolidate)
# -> 1774         mgr = BlockManager(blocks, axes)
#    1775     except ValueError as e:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, verify_integrity)
#     913
# --> 914             self._verify_integrity()
#     915
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     920             if block.shape[1:] != mgr_shape[1:]:
# --> 921                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     922         if len(self.items) != tot_items:
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
plt.pie(y,labels=mylabels,startangle=90)
plt.show()
